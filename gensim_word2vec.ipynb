# %% [markdown]
# Using Gensim Word2Vec to create a food-related word embedding.
# See [https://www.kaggle.com/pierremegret/gensim-word2vec-tutorial](https://www.kaggle.com/pierremegret/gensim-word2vec-tutorial)

# %% [markdown]
# Connect to my Google Drive so I don't have to upload reviews.csv every time.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import re # For preprocessing
import pandas as pd # For data handling
from time import time # To time our operations
from collections import defaultdict # For word frequency

import spacy # For preprocessing

import logging # Setting up the loggings to monitor gensim
logging.basicConfig(format="5(levelnames)s - %(asctime)s: %(message)s", 
                    datefmt = '%H%M%S', level=logging.INFO)

# %% [markdown]
# We are using the Food.com dataset prepared by Alvin on Kaggle: [https://www.kaggle.com/irkaal/foodcom-recipes-and-reviews](https://www.kaggle.com/irkaal/foodcom-recipes-and-reviews)

# %%
df = pd.read_csv('/content/drive/MyDrive/reviews.csv') # read in the review dataset
df.head() #check the column names
# Out:
#    ReviewId  RecipeId  ...         DateSubmitted          DateModified
# 0         2       992  ...  2000-01-25T21:44:00Z  2000-01-25T21:44:00Z
# 1         7      4384  ...  2001-10-17T16:49:59Z  2001-10-17T16:49:59Z
# 2         9      4523  ...  2000-02-25T09:00:00Z  2000-02-25T09:00:00Z
# 3        13      7435  ...  2000-03-13T21:15:00Z  2000-03-13T21:15:00Z
# 4        14        44  ...  2000-03-28T12:51:00Z  2000-03-28T12:51:00Z
#
# [5 rows x 8 columns]

# %%
# Remove blank reviews/those without text
df=df.dropna().reset_index(drop=True)
df.isnull().sum()
# Out:
# 5(levelnames)s - 212753: NumExpr defaulting to 2 threads.
# ReviewId         0
# RecipeId         0
# AuthorId         0
# AuthorName       0
# Rating           0
# Review           0
# DateSubmitted    0
# DateModified     0
# dtype: int64

# %%
nlp = spacy.load('en', disable = ['ner', 'parser']) #disabling Named Entity Recognition for speed

def cleaning(doc): 
  #function that lemmatizes and removes stopwords: i.e.) running, ran, run get converted to baseword "run"
  # doc needs to be a spacy Doc object

  txt = [token.lemma_ for token in doc if not token.is_stop]
  # lemmatizes each word in doc, if it is not a stopword

  if len(txt) > 2:
    return ' '.join(txt)
    # converts list of words back to single string with spaces. 
    # i.e) "the cat ran" -> "the, cat, ran" -> "cat run"

# %%
#Remove non alphabetic characters and convert everything to lower case
#brief_cleaning is an interator; each "object" in the iterator is a cleaned review. 

brief_cleaning = (re.sub("[^A-Za-z']+", ' ', str(row)).lower() for row in df['Review'])

# %%
df_clean = pd.read_csv('/content/drive/MyDrive/cleaned_reviews.csv')

# %%
from gensim.models.phrases import Phrases, Phraser

# %%
list_of_lists = [row.split() for row in df_clean['clean']]

# %%
phrases = Phrases(list_of_lists, progress_per = 10000)
# Out:
# 5(levelnames)s - 213152: collecting all words and their counts
# 5(levelnames)s - 213152: PROGRESS: at sentence #0, processed 0 words and 0 word types
# 5(levelnames)s - 213152: PROGRESS: at sentence #10000, processed 171802 words and 104901 word types
# 5(levelnames)s - 213152: PROGRESS: at sentence #20000, processed 381565 words and 194204 word types
# 5(levelnames)s - 213153: PROGRESS: at sentence #30000, processed 600679 words and 273256 word types
# 5(levelnames)s - 213153: PROGRESS: at sentence #40000, processed 820978 words and 342611 word types
# 5(levelnames)s - 213153: PROGRESS: at sentence #50000, processed 1044448 words and 408364 word types
# 5(levelnames)s - 213154: PROGRESS: at sentence #60000, processed 1263537 words and 469121 word types
# 5(levelnames)s - 213154: PROGRESS: at sentence #70000, processed 1480796 words and 524683 word types
# 5(levelnames)s - 213154: PROGRESS: at sentence #80000, processed 1695036 words and 576187 word types
# 5(levelnames)s - 213155: PROGRESS: at sentence #90000, processed 1915243 words and 626336 word types
# 5(levelnames)s - 213155: PROGRESS: at sentence #100000, processed 2139083 words and 676018 word types
# 5(levelnames)s - 213156: PROGRESS: at sentence #110000, processed 2357277 words and 723084 word types
# 5(levelnames)s - 213156: PROGRESS: at sentence #120000, processed 2585109 words and 770479 word types
# 5(levelnames)s - 213157: PROGRESS: at sentence #130000, processed 2809760 words and 815968 word types
# 5(levelnames)s - 213157: PROGRESS: at sentence #140000, processed 3034745 words and 860213 word types
# 5(levelnames)s - 213157: PROGRESS: at sentence #150000, processed 3249717 words and 900897 word types
# 5(levelnames)s - 213158: PROGRESS: at sentence #160000, processed 3469707 words and 942368 word types
# 5(levelnames)s - 213158: PROGRESS: at sentence #170000, processed 3684051 words and 982273 word types
# 5(levelnames)s - 213159: PROGRESS: at sentence #180000, processed 3894594 words and 1020901 word types
# 5(levelnames)s - 213159: PROGRESS: at sentence #190000, processed 4105521 words and 1058990 word types
# 5(levelnames)s - 213159: PROGRESS: at sentence #200000, processed 4321207 words and 1096957 word types
# 5(levelnames)s - 213200: PROGRESS: at sentence #210000, processed 4534936 words and 1133469 word types
# 5(levelnames)s - 213200: PROGRESS: at sentence #220000, processed 4746724 words and 1169360 word types
# 5(levelnames)s - 213201: PROGRESS: at sentence #230000, processed 4959039 words and 1202630 word types
# 5(levelnames)s - 213201: PROGRESS: at sentence #240000, processed 5168580 words and 1235738 word types
# 5(levelnames)s - 213201: PROGRESS: at sentence #250000, processed 5379890 words and 1268442 word types
# 5(levelnames)s - 213202: PROGRESS: at sentence #260000, processed 5590967 words and 1301305 word types
# 5(levelnames)s - 213202: PROGRESS: at sentence #270000, processed 5794341 words and 1333927 word types
# 5(levelnames)s - 213203: PROGRESS: at sentence #280000, processed 6003364 words and 1365634 word types
# 5(levelnames)s - 213203: PROGRESS: at sentence #290000, processed 6218691 words and 1397515 word types
# 5(levelnames)s - 213203: PROGRESS: at sentence #300000, processed 6439379 words and 1429851 word types
# 5(levelnames)s - 213204: PROGRESS: at sentence #310000, processed 6655379 words and 1460801 word types
# 5(levelnames)s - 213204: PROGRESS: at sentence #320000, processed 6865875 words and 1491055 word types
# 5(levelnames)s - 213205: PROGRESS: at sentence #330000, processed 7084804 words and 1522376 word types
# 5(levelnames)s - 213205: PROGRESS: at sentence #340000, processed 7311617 words and 1553744 word types
# 5(levelnames)s - 213205: PROGRESS: at sentence #350000, processed 7531967 words and 1583291 word types
# 5(levelnames)s - 213206: PROGRESS: at sentence #360000, processed 7758845 words and 1615031 word types
# 5(levelnames)s - 213206: PROGRESS: at sentence #370000, processed 7982761 words and 1645536 word types
# 5(levelnames)s - 213207: PROGRESS: at sentence #380000, processed 8207550 words and 1675487 word types
# 5(levelnames)s - 213207: PROGRESS: at sentence #390000, processed 8428879 words and 1705560 word types
# 5(levelnames)s - 213208: PROGRESS: at sentence #400000, processed 8647378 words and 1735961 word types
# 5(levelnames)s - 213208: PROGRESS: at sentence #410000, processed 8864773 words and 1764976 word types
# 5(levelnames)s - 213208: PROGRESS: at sentence #420000, processed 9080446 words and 1792637 word types
# 5(levelnames)s - 213209: PROGRESS: at sentence #430000, processed 9305870 words and 1821237 word types
# 5(levelnames)s - 213209: PROGRESS: at sentence #440000, processed 9529017 words and 1849508 word types
# 5(levelnames)s - 213210: PROGRESS: at sentence #450000, processed 9751447 words and 1877114 word types
# 5(levelnames)s - 213210: PROGRESS: at sentence #460000, processed 9969327 words and 1903216 word types
# 5(levelnames)s - 213210: PROGRESS: at sentence #470000, processed 10183834 words and 1928833 word types
# 5(levelnames)s - 213211: PROGRESS: at sentence #480000, processed 10394344 words and 1953993 word types
# 5(levelnames)s - 213211: PROGRESS: at sentence #490000, processed 10608213 words and 1980452 word types
# 5(levelnames)s - 213212: PROGRESS: at sentence #500000, processed 10822846 words and 2005680 word types
# 5(levelnames)s - 213212: PROGRESS: at sentence #510000, processed 11038252 words and 2029437 word types
# 5(levelnames)s - 213213: PROGRESS: at sentence #520000, processed 11255861 words and 2053464 word types
# 5(levelnames)s - 213213: PROGRESS: at sentence #530000, processed 11474763 words and 2078476 word types
# 5(levelnames)s - 213213: PROGRESS: at sentence #540000, processed 11700702 words and 2104221 word types
# 5(levelnames)s - 213214: PROGRESS: at sentence #550000, processed 11928139 words and 2129990 word types
# 5(levelnames)s - 213214: PROGRESS: at sentence #560000, processed 12160447 words and 2155826 word types
# 5(levelnames)s - 213215: PROGRESS: at sentence #570000, processed 12393332 words and 2182180 word types
# 5(levelnames)s - 213215: PROGRESS: at sentence #580000, processed 12624056 words and 2208134 word types
# 5(levelnames)s - 213215: PROGRESS: at sentence #590000, processed 12851062 words and 2234100 word types
# 5(levelnames)s - 213216: PROGRESS: at sentence #600000, processed 13076481 words and 2259548 word types
# 5(levelnames)s - 213216: PROGRESS: at sentence #610000, processed 13303075 words and 2284958 word types
# 5(levelnames)s - 213217: PROGRESS: at sentence #620000, processed 13533345 words and 2309901 word types
# 5(levelnames)s - 213217: PROGRESS: at sentence #630000, processed 13766580 words and 2334823 word types
# 5(levelnames)s - 213218: PROGRESS: at sentence #640000, processed 13995964 words and 2358555 word types
# 5(levelnames)s - 213218: PROGRESS: at sentence #650000, processed 14225773 words and 2382348 word types
# 5(levelnames)s - 213219: PROGRESS: at sentence #660000, processed 14453894 words and 2405871 word types
# 5(levelnames)s - 213219: PROGRESS: at sentence #670000, processed 14680729 words and 2429144 word types
# 5(levelnames)s - 213219: PROGRESS: at sentence #680000, processed 14908123 words and 2453051 word types
# 5(levelnames)s - 213220: PROGRESS: at sentence #690000, processed 15131807 words and 2476718 word types
# 5(levelnames)s - 213220: PROGRESS: at sentence #700000, processed 15358277 words and 2500359 word types
# 5(levelnames)s - 213221: PROGRESS: at sentence #710000, processed 15586232 words and 2523092 word types
# 5(levelnames)s - 213221: PROGRESS: at sentence #720000, processed 15815497 words and 2545990 word types
# 5(levelnames)s - 213222: PROGRESS: at sentence #730000, processed 16046477 words and 2569157 word types
# 5(levelnames)s - 213222: PROGRESS: at sentence #740000, processed 16273719 words and 2590933 word types
# 5(levelnames)s - 213223: PROGRESS: at sentence #750000, processed 16505801 words and 2613266 word types
# 5(levelnames)s - 213223: PROGRESS: at sentence #760000, processed 16729146 words and 2634651 word types
# 5(levelnames)s - 213223: PROGRESS: at sentence #770000, processed 16956735 words and 2657239 word types
# 5(levelnames)s - 213224: PROGRESS: at sentence #780000, processed 17184078 words and 2680881 word types
# 5(levelnames)s - 213224: PROGRESS: at sentence #790000, processed 17411660 words and 2703427 word types
# 5(levelnames)s - 213225: PROGRESS: at sentence #800000, processed 17636134 words and 2725619 word types
# 5(levelnames)s - 213225: PROGRESS: at sentence #810000, processed 17859394 words and 2747565 word types
# 5(levelnames)s - 213226: PROGRESS: at sentence #820000, processed 18081694 words and 2768969 word types
# 5(levelnames)s - 213226: PROGRESS: at sentence #830000, processed 18308881 words and 2790960 word types
# 5(levelnames)s - 213227: PROGRESS: at sentence #840000, processed 18534079 words and 2811972 word types
# 5(levelnames)s - 213227: PROGRESS: at sentence #850000, processed 18754135 words and 2832104 word types
# 5(levelnames)s - 213228: PROGRESS: at sentence #860000, processed 18976674 words and 2852557 word types
# 5(levelnames)s - 213228: PROGRESS: at sentence #870000, processed 19199417 words and 2873286 word types
# 5(levelnames)s - 213228: PROGRESS: at sentence #880000, processed 19420268 words and 2894149 word types
# 5(levelnames)s - 213229: PROGRESS: at sentence #890000, processed 19644462 words and 2914214 word types
# 5(levelnames)s - 213229: PROGRESS: at sentence #900000, processed 19868589 words and 2933876 word types
# 5(levelnames)s - 213230: PROGRESS: at sentence #910000, processed 20093168 words and 2953593 word types
# 5(levelnames)s - 213230: PROGRESS: at sentence #920000, processed 20324873 words and 2974097 word types
# 5(levelnames)s - 213231: PROGRESS: at sentence #930000, processed 20558724 words and 2994555 word types
# 5(levelnames)s - 213231: PROGRESS: at sentence #940000, processed 20790311 words and 3015090 word types
# 5(levelnames)s - 213231: PROGRESS: at sentence #950000, processed 21016519 words and 3035649 word types
# 5(levelnames)s - 213232: PROGRESS: at sentence #960000, processed 21238730 words and 3056502 word types
# 5(levelnames)s - 213232: PROGRESS: at sentence #970000, processed 21461601 words and 3076812 word types
# 5(levelnames)s - 213233: PROGRESS: at sentence #980000, processed 21693451 words and 3097441 word types
# 5(levelnames)s - 213233: PROGRESS: at sentence #990000, processed 21931801 words and 3118377 word types
# 5(levelnames)s - 213234: PROGRESS: at sentence #1000000, processed 22172404 words and 3139646 word types
# 5(levelnames)s - 213234: PROGRESS: at sentence #1010000, processed 22415804 words and 3161638 word types
# 5(levelnames)s - 213235: PROGRESS: at sentence #1020000, processed 22662456 words and 3183165 word types
# 5(levelnames)s - 213235: PROGRESS: at sentence #1030000, processed 22911962 words and 3204335 word types
# 5(levelnames)s - 213236: PROGRESS: at sentence #1040000, processed 23151101 words and 3224772 word types
# 5(levelnames)s - 213236: PROGRESS: at sentence #1050000, processed 23389421 words and 3245498 word types
# 5(levelnames)s - 213237: PROGRESS: at sentence #1060000, processed 23630196 words and 3266739 word types
# 5(levelnames)s - 213237: PROGRESS: at sentence #1070000, processed 23869326 words and 3287150 word types
# 5(levelnames)s - 213237: PROGRESS: at sentence #1080000, processed 24115858 words and 3307483 word types
# 5(levelnames)s - 213238: PROGRESS: at sentence #1090000, processed 24356262 words and 3327616 word types
# 5(levelnames)s - 213238: PROGRESS: at sentence #1100000, processed 24597558 words and 3347760 word types
# 5(levelnames)s - 213239: PROGRESS: at sentence #1110000, processed 24831225 words and 3367331 word types
# 5(levelnames)s - 213239: PROGRESS: at sentence #1120000, processed 25075197 words and 3388250 word types
# 5(levelnames)s - 213240: PROGRESS: at sentence #1130000, processed 25317619 words and 3409871 word types
# 5(levelnames)s - 213240: PROGRESS: at sentence #1140000, processed 25558751 words and 3433038 word types
# 5(levelnames)s - 213241: PROGRESS: at sentence #1150000, processed 25791813 words and 3452758 word types
# 5(levelnames)s - 213241: PROGRESS: at sentence #1160000, processed 26038235 words and 3474890 word types
# 5(levelnames)s - 213242: PROGRESS: at sentence #1170000, processed 26273459 words and 3495477 word types
# 5(levelnames)s - 213242: PROGRESS: at sentence #1180000, processed 26530467 words and 3520282 word types
# 5(levelnames)s - 213243: PROGRESS: at sentence #1190000, processed 26790886 words and 3544361 word types
# 5(levelnames)s - 213243: PROGRESS: at sentence #1200000, processed 27041152 words and 3566141 word types
# 5(levelnames)s - 213244: PROGRESS: at sentence #1210000, processed 27307440 words and 3589444 word types
# 5(levelnames)s - 213244: PROGRESS: at sentence #1220000, processed 27573967 words and 3612673 word types
# 5(levelnames)s - 213245: PROGRESS: at sentence #1230000, processed 27834038 words and 3634153 word types
# 5(levelnames)s - 213245: PROGRESS: at sentence #1240000, processed 28083038 words and 3656554 word types
# 5(levelnames)s - 213245: PROGRESS: at sentence #1250000, processed 28340941 words and 3678773 word types
# 5(levelnames)s - 213246: PROGRESS: at sentence #1260000, processed 28583636 words and 3700620 word types
# 5(levelnames)s - 213246: PROGRESS: at sentence #1270000, processed 28818288 words and 3722786 word types
# 5(levelnames)s - 213247: PROGRESS: at sentence #1280000, processed 29062182 words and 3744769 word types
# 5(levelnames)s - 213247: PROGRESS: at sentence #1290000, processed 29297105 words and 3766924 word types
# 5(levelnames)s - 213248: PROGRESS: at sentence #1300000, processed 29514945 words and 3787786 word types
# 5(levelnames)s - 213248: PROGRESS: at sentence #1310000, processed 29723890 words and 3808730 word types
# 5(levelnames)s - 213248: PROGRESS: at sentence #1320000, processed 29935267 words and 3830087 word types
# 5(levelnames)s - 213249: PROGRESS: at sentence #1330000, processed 30140333 words and 3850611 word types
# 5(levelnames)s - 213249: PROGRESS: at sentence #1340000, processed 30345933 words and 3871338 word types
# 5(levelnames)s - 213250: PROGRESS: at sentence #1350000, processed 30550947 words and 3891486 word types
# 5(levelnames)s - 213250: PROGRESS: at sentence #1360000, processed 30765928 words and 3910690 word types
# 5(levelnames)s - 213250: collected 3929266 word types from a corpus of 30965969 words (unigram + bigrams) and 1369346 sentences
# 5(levelnames)s - 213250: using 3929266 counts as vocab in Phrases<0 vocab, min_count=5, threshold=10.0, max_vocab_size=40000000>

# %%
bigram = Phraser(phrases)
# Out:
# 5(levelnames)s - 213427: source_vocab length 3929266
# 5(levelnames)s - 213508: Phraser built with 16928 phrasegrams

# %%
sentences = bigram[list_of_lists]

# %%
word_freq = defaultdict(int)
for sent in sentences:
  for word in sent:
    word_freq[word] += 1
len(word_freq)
# Out:
# 138866

# %%
sorted(word_freq, key=word_freq.get, reverse=True)[:10]
# Out:
# ['recipe',
#  'thank',
#  'add',
#  'good',
#  'great',
#  'love',
#  'time',
#  'like',
#  'easy',
#  'taste']

# %%
import multiprocessing
from gensim.models import Word2Vec

# %%
cores = multiprocessing.cpu_count() #Count the number of cores in a computer

# %%
w2v_model = Word2Vec(min_count = 100, 
                     window = 2,
                     size = 300,
                     sample = 6e-5,
                     alpha = 0.03,
                     min_alpha = 0.0007,
                     negative = 20,
                     workers = cores-1)

# %%
t = time()
w2v_model.build_vocab(sentences, progress_per=10000)

print('Time to build vocab: {} mins'.format(round((time()-t)/60, 2)))
# Out:
# 5(levelnames)s - 214750: collecting all words and their counts
# 5(levelnames)s - 214750: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 5(levelnames)s - 214751: PROGRESS: at sentence #10000, processed 161663 words, keeping 11339 word types
# 5(levelnames)s - 214752: PROGRESS: at sentence #20000, processed 358885 words, keeping 17018 word types
# 5(levelnames)s - 214752: PROGRESS: at sentence #30000, processed 564703 words, keeping 21196 word types
# 5(levelnames)s - 214753: PROGRESS: at sentence #40000, processed 771435 words, keeping 24533 word types
# 5(levelnames)s - 214753: PROGRESS: at sentence #50000, processed 981267 words, keeping 27528 word types
# 5(levelnames)s - 214754: PROGRESS: at sentence #60000, processed 1187241 words, keeping 30262 word types
# 5(levelnames)s - 214755: PROGRESS: at sentence #70000, processed 1391284 words, keeping 32680 word types
# 5(levelnames)s - 214755: PROGRESS: at sentence #80000, processed 1592336 words, keeping 34813 word types
# 5(levelnames)s - 214756: PROGRESS: at sentence #90000, processed 1798850 words, keeping 36866 word types
# 5(levelnames)s - 214757: PROGRESS: at sentence #100000, processed 2009204 words, keeping 38886 word types
# 5(levelnames)s - 214757: PROGRESS: at sentence #110000, processed 2213909 words, keeping 40741 word types
# 5(levelnames)s - 214758: PROGRESS: at sentence #120000, processed 2427840 words, keeping 42605 word types
# 5(levelnames)s - 214759: PROGRESS: at sentence #130000, processed 2638744 words, keeping 44382 word types
# 5(levelnames)s - 214759: PROGRESS: at sentence #140000, processed 2849810 words, keeping 45971 word types
# 5(levelnames)s - 214800: PROGRESS: at sentence #150000, processed 3051546 words, keeping 47535 word types
# 5(levelnames)s - 214800: PROGRESS: at sentence #160000, processed 3258174 words, keeping 49086 word types
# 5(levelnames)s - 214801: PROGRESS: at sentence #170000, processed 3459412 words, keeping 50571 word types
# 5(levelnames)s - 214802: PROGRESS: at sentence #180000, processed 3657298 words, keeping 52036 word types
# 5(levelnames)s - 214802: PROGRESS: at sentence #190000, processed 3855211 words, keeping 53525 word types
# 5(levelnames)s - 214803: PROGRESS: at sentence #200000, processed 4057863 words, keeping 54900 word types
# 5(levelnames)s - 214804: PROGRESS: at sentence #210000, processed 4258461 words, keeping 56205 word types
# 5(levelnames)s - 214804: PROGRESS: at sentence #220000, processed 4457154 words, keeping 57430 word types
# 5(levelnames)s - 214805: PROGRESS: at sentence #230000, processed 4656140 words, keeping 58613 word types
# 5(levelnames)s - 214805: PROGRESS: at sentence #240000, processed 4852632 words, keeping 59790 word types
# 5(levelnames)s - 214806: PROGRESS: at sentence #250000, processed 5050650 words, keeping 60893 word types
# 5(levelnames)s - 214807: PROGRESS: at sentence #260000, processed 5248650 words, keeping 62040 word types
# 5(levelnames)s - 214807: PROGRESS: at sentence #270000, processed 5439460 words, keeping 63164 word types
# 5(levelnames)s - 214808: PROGRESS: at sentence #280000, processed 5635527 words, keeping 64264 word types
# 5(levelnames)s - 214809: PROGRESS: at sentence #290000, processed 5837448 words, keeping 65308 word types
# 5(levelnames)s - 214809: PROGRESS: at sentence #300000, processed 6044456 words, keeping 66392 word types
# 5(levelnames)s - 214810: PROGRESS: at sentence #310000, processed 6247071 words, keeping 67437 word types
# 5(levelnames)s - 214811: PROGRESS: at sentence #320000, processed 6444570 words, keeping 68422 word types
# 5(levelnames)s - 214811: PROGRESS: at sentence #330000, processed 6649512 words, keeping 69360 word types
# 5(levelnames)s - 214812: PROGRESS: at sentence #340000, processed 6861752 words, keeping 70374 word types
# 5(levelnames)s - 214813: PROGRESS: at sentence #350000, processed 7067863 words, keeping 71327 word types
# 5(levelnames)s - 214813: PROGRESS: at sentence #360000, processed 7280217 words, keeping 72331 word types
# 5(levelnames)s - 214814: PROGRESS: at sentence #370000, processed 7489734 words, keeping 73300 word types
# 5(levelnames)s - 214815: PROGRESS: at sentence #380000, processed 7699983 words, keeping 74172 word types
# 5(levelnames)s - 214815: PROGRESS: at sentence #390000, processed 7907076 words, keeping 75084 word types
# 5(levelnames)s - 214816: PROGRESS: at sentence #400000, processed 8111512 words, keeping 76055 word types
# 5(levelnames)s - 214816: PROGRESS: at sentence #410000, processed 8314981 words, keeping 76935 word types
# 5(levelnames)s - 214817: PROGRESS: at sentence #420000, processed 8516844 words, keeping 77809 word types
# 5(levelnames)s - 214818: PROGRESS: at sentence #430000, processed 8728242 words, keeping 78656 word types
# 5(levelnames)s - 214818: PROGRESS: at sentence #440000, processed 8937098 words, keeping 79565 word types
# 5(levelnames)s - 214819: PROGRESS: at sentence #450000, processed 9144666 words, keeping 80447 word types
# 5(levelnames)s - 214820: PROGRESS: at sentence #460000, processed 9348120 words, keeping 81283 word types
# 5(levelnames)s - 214820: PROGRESS: at sentence #470000, processed 9548955 words, keeping 82056 word types
# 5(levelnames)s - 214821: PROGRESS: at sentence #480000, processed 9746298 words, keeping 82810 word types
# 5(levelnames)s - 214822: PROGRESS: at sentence #490000, processed 9946496 words, keeping 83598 word types
# 5(levelnames)s - 214822: PROGRESS: at sentence #500000, processed 10147403 words, keeping 84359 word types
# 5(levelnames)s - 214823: PROGRESS: at sentence #510000, processed 10348582 words, keeping 85076 word types
# 5(levelnames)s - 214824: PROGRESS: at sentence #520000, processed 10551711 words, keeping 85829 word types
# 5(levelnames)s - 214824: PROGRESS: at sentence #530000, processed 10756231 words, keeping 86547 word types
# 5(levelnames)s - 214825: PROGRESS: at sentence #540000, processed 10967248 words, keeping 87364 word types
# 5(levelnames)s - 214826: PROGRESS: at sentence #550000, processed 11179678 words, keeping 88154 word types
# 5(levelnames)s - 214826: PROGRESS: at sentence #560000, processed 11395803 words, keeping 89011 word types
# 5(levelnames)s - 214827: PROGRESS: at sentence #570000, processed 11612788 words, keeping 89791 word types
# 5(levelnames)s - 214828: PROGRESS: at sentence #580000, processed 11827920 words, keeping 90607 word types
# 5(levelnames)s - 214828: PROGRESS: at sentence #590000, processed 12039325 words, keeping 91353 word types
# 5(levelnames)s - 214829: PROGRESS: at sentence #600000, processed 12248831 words, keeping 92055 word types
# 5(levelnames)s - 214830: PROGRESS: at sentence #610000, processed 12460395 words, keeping 92797 word types
# 5(levelnames)s - 214830: PROGRESS: at sentence #620000, processed 12675138 words, keeping 93541 word types
# 5(levelnames)s - 214831: PROGRESS: at sentence #630000, processed 12893088 words, keeping 94210 word types
# 5(levelnames)s - 214832: PROGRESS: at sentence #640000, processed 13106717 words, keeping 94883 word types
# 5(levelnames)s - 214832: PROGRESS: at sentence #650000, processed 13320425 words, keeping 95606 word types
# 5(levelnames)s - 214833: PROGRESS: at sentence #660000, processed 13532668 words, keeping 96329 word types
# 5(levelnames)s - 214834: PROGRESS: at sentence #670000, processed 13744373 words, keeping 96992 word types
# 5(levelnames)s - 214834: PROGRESS: at sentence #680000, processed 13956928 words, keeping 97732 word types
# 5(levelnames)s - 214835: PROGRESS: at sentence #690000, processed 14165718 words, keeping 98413 word types
# 5(levelnames)s - 214836: PROGRESS: at sentence #700000, processed 14376740 words, keeping 99041 word types
# 5(levelnames)s - 214837: PROGRESS: at sentence #710000, processed 14589237 words, keeping 99694 word types
# 5(levelnames)s - 214837: PROGRESS: at sentence #720000, processed 14803271 words, keeping 100304 word types
# 5(levelnames)s - 214838: PROGRESS: at sentence #730000, processed 15018945 words, keeping 100956 word types
# 5(levelnames)s - 214839: PROGRESS: at sentence #740000, processed 15230958 words, keeping 101614 word types
# 5(levelnames)s - 214839: PROGRESS: at sentence #750000, processed 15446621 words, keeping 102302 word types
# 5(levelnames)s - 214840: PROGRESS: at sentence #760000, processed 15654225 words, keeping 102909 word types
# 5(levelnames)s - 214841: PROGRESS: at sentence #770000, processed 15866080 words, keeping 103678 word types
# 5(levelnames)s - 214841: PROGRESS: at sentence #780000, processed 16077047 words, keeping 104458 word types
# 5(levelnames)s - 214842: PROGRESS: at sentence #790000, processed 16288817 words, keeping 105141 word types
# 5(levelnames)s - 214843: PROGRESS: at sentence #800000, processed 16497662 words, keeping 105734 word types
# 5(levelnames)s - 214843: PROGRESS: at sentence #810000, processed 16705821 words, keeping 106324 word types
# 5(levelnames)s - 214844: PROGRESS: at sentence #820000, processed 16913235 words, keeping 106947 word types
# 5(levelnames)s - 214845: PROGRESS: at sentence #830000, processed 17124721 words, keeping 107611 word types
# 5(levelnames)s - 214845: PROGRESS: at sentence #840000, processed 17333600 words, keeping 108243 word types
# 5(levelnames)s - 214846: PROGRESS: at sentence #850000, processed 17538650 words, keeping 108789 word types
# 5(levelnames)s - 214847: PROGRESS: at sentence #860000, processed 17746242 words, keeping 109349 word types
# 5(levelnames)s - 214847: PROGRESS: at sentence #870000, processed 17954285 words, keeping 109970 word types
# 5(levelnames)s - 214848: PROGRESS: at sentence #880000, processed 18160484 words, keeping 110529 word types
# 5(levelnames)s - 214849: PROGRESS: at sentence #890000, processed 18369191 words, keeping 111047 word types
# 5(levelnames)s - 214849: PROGRESS: at sentence #900000, processed 18577822 words, keeping 111577 word types
# 5(levelnames)s - 214850: PROGRESS: at sentence #910000, processed 18787018 words, keeping 112121 word types
# 5(levelnames)s - 214851: PROGRESS: at sentence #920000, processed 19002692 words, keeping 112644 word types
# 5(levelnames)s - 214851: PROGRESS: at sentence #930000, processed 19219327 words, keeping 113211 word types
# 5(levelnames)s - 214852: PROGRESS: at sentence #940000, processed 19433257 words, keeping 113809 word types
# 5(levelnames)s - 214853: PROGRESS: at sentence #950000, processed 19643422 words, keeping 114422 word types
# 5(levelnames)s - 214853: PROGRESS: at sentence #960000, processed 19849640 words, keeping 115016 word types
# 5(levelnames)s - 214854: PROGRESS: at sentence #970000, processed 20056778 words, keeping 115528 word types
# 5(levelnames)s - 214854: PROGRESS: at sentence #980000, processed 20272977 words, keeping 116031 word types
# 5(levelnames)s - 214855: PROGRESS: at sentence #990000, processed 20494587 words, keeping 116651 word types
# 5(levelnames)s - 214856: PROGRESS: at sentence #1000000, processed 20718914 words, keeping 117220 word types
# 5(levelnames)s - 214857: PROGRESS: at sentence #1010000, processed 20945374 words, keeping 117785 word types
# 5(levelnames)s - 214857: PROGRESS: at sentence #1020000, processed 21174508 words, keeping 118351 word types
# 5(levelnames)s - 214858: PROGRESS: at sentence #1030000, processed 21405433 words, keeping 118971 word types
# 5(levelnames)s - 214859: PROGRESS: at sentence #1040000, processed 21627426 words, keeping 119540 word types
# 5(levelnames)s - 214859: PROGRESS: at sentence #1050000, processed 21848978 words, keeping 120109 word types
# 5(levelnames)s - 214900: PROGRESS: at sentence #1060000, processed 22072441 words, keeping 120671 word types
# 5(levelnames)s - 214901: PROGRESS: at sentence #1070000, processed 22295038 words, keeping 121183 word types
# 5(levelnames)s - 214902: PROGRESS: at sentence #1080000, processed 22523762 words, keeping 121684 word types
# 5(levelnames)s - 214902: PROGRESS: at sentence #1090000, processed 22747458 words, keeping 122302 word types
# 5(levelnames)s - 214903: PROGRESS: at sentence #1100000, processed 22971876 words, keeping 122861 word types
# 5(levelnames)s - 214904: PROGRESS: at sentence #1110000, processed 23189050 words, keeping 123400 word types
# 5(levelnames)s - 214904: PROGRESS: at sentence #1120000, processed 23414806 words, keeping 124022 word types
# 5(levelnames)s - 214905: PROGRESS: at sentence #1130000, processed 23640202 words, keeping 124610 word types
# 5(levelnames)s - 214906: PROGRESS: at sentence #1140000, processed 23864230 words, keeping 125241 word types
# 5(levelnames)s - 214906: PROGRESS: at sentence #1150000, processed 24080611 words, keeping 125827 word types
# 5(levelnames)s - 214907: PROGRESS: at sentence #1160000, processed 24310037 words, keeping 126412 word types
# 5(levelnames)s - 214908: PROGRESS: at sentence #1170000, processed 24528851 words, keeping 126999 word types
# 5(levelnames)s - 214909: PROGRESS: at sentence #1180000, processed 24763922 words, keeping 127549 word types
# 5(levelnames)s - 214909: PROGRESS: at sentence #1190000, processed 25001878 words, keeping 128154 word types
# 5(levelnames)s - 214910: PROGRESS: at sentence #1200000, processed 25231158 words, keeping 128594 word types
# 5(levelnames)s - 214911: PROGRESS: at sentence #1210000, processed 25474933 words, keeping 129141 word types
# 5(levelnames)s - 214912: PROGRESS: at sentence #1220000, processed 25718636 words, keeping 129662 word types
# 5(levelnames)s - 214912: PROGRESS: at sentence #1230000, processed 25956064 words, keeping 130165 word types
# 5(levelnames)s - 214913: PROGRESS: at sentence #1240000, processed 26183616 words, keeping 130714 word types
# 5(levelnames)s - 214914: PROGRESS: at sentence #1250000, processed 26419567 words, keeping 131284 word types
# 5(levelnames)s - 214915: PROGRESS: at sentence #1260000, processed 26643835 words, keeping 131911 word types
# 5(levelnames)s - 214915: PROGRESS: at sentence #1270000, processed 26861226 words, keeping 132567 word types
# 5(levelnames)s - 214916: PROGRESS: at sentence #1280000, processed 27087175 words, keeping 133151 word types
# 5(levelnames)s - 214916: PROGRESS: at sentence #1290000, processed 27306753 words, keeping 133789 word types
# 5(levelnames)s - 214917: PROGRESS: at sentence #1300000, processed 27510730 words, keeping 134464 word types
# 5(levelnames)s - 214918: PROGRESS: at sentence #1310000, processed 27706124 words, keeping 135174 word types
# 5(levelnames)s - 214918: PROGRESS: at sentence #1320000, processed 27903971 words, keeping 135865 word types
# 5(levelnames)s - 214919: PROGRESS: at sentence #1330000, processed 28095683 words, keeping 136525 word types
# 5(levelnames)s - 214920: PROGRESS: at sentence #1340000, processed 28287805 words, keeping 137230 word types
# 5(levelnames)s - 214920: PROGRESS: at sentence #1350000, processed 28479120 words, keeping 137839 word types
# 5(levelnames)s - 214921: PROGRESS: at sentence #1360000, processed 28679620 words, keeping 138358 word types
# 5(levelnames)s - 214921: collected 138866 word types from a corpus of 28866702 raw words and 1369346 sentences
# 5(levelnames)s - 214921: Loading a fresh vocabulary
# 5(levelnames)s - 214921: effective_min_count=100 retains 8561 unique words (6% of original 138866, drops 130305)
# 5(levelnames)s - 214921: effective_min_count=100 leaves 27931845 word corpus (96% of original 28866702, drops 934857)
# 5(levelnames)s - 214922: deleting the raw counts dictionary of 138866 items
# 5(levelnames)s - 214922: sample=6e-05 downsamples 905 most-common words
# 5(levelnames)s - 214922: downsampling leaves estimated 11195032 word corpus (40.1% of prior 27931845)
# 5(levelnames)s - 214922: estimated required memory for 8561 words and 300 dimensions: 24826900 bytes
words/s, in_qsize 0, out_qsize 0
# 5(levelnames)s - 220400: EPOCH 5 - PROGRESS: at 91.32% examples, 71107 words/s, in_qsize 0, out_qsize 0
# 5(levelnames)s - 220401: EPOCH 5 - PROGRESS: at 92.01% examples, 71183 words/s, in_qsize 0, out_qsize 0
# 5(levelnames)s - 220402: EPOCH 5 - PROGRESS: at 92.71% examples, 71271 words/s, in_qsize 0, out_qsize 0
# 5(levelnames)s - 220403: EPOCH 5 - PROGRESS: at 93.42% examples, 71363 words/s, in_qsize 0, out_qsize 0
# 5(levelnames)s - 220404: EPOCH 5 - PROGRESS: at 94.12% examples, 71441 words/s, in_qsize 0, out_qsize 0
# 5(levelnames)s - 220405: EPOCH 5 - PROGRESS: at 94.82% examples, 71484 words/s, in_qsize 2, out_qsize 0
# 5(levelnames)s - 220406: EPOCH 5 - PROGRESS: at 95.60% examples, 71564 words/s, in_qsize 1, out_qsize 0
# 5(levelnames)s - 220407: EPOCH 5 - PROGRESS: at 96.38% examples, 71644 words/s, in_qsize 1, out_qsize 0
# 5(levelnames)s - 220408: EPOCH 5 - PROGRESS: at 97.18% examples, 71721 words/s, in_qsize 0, out_qsize 0
# 5(levelnames)s - 220409: EPOCH 5 - PROGRESS: at 97.98% examples, 71792 words/s, in_qsize 1, out_qsize 0
# 5(levelnames)s - 220410: EPOCH 5 - PROGRESS: at 98.77% examples, 71864 words/s, in_qsize 0, out_qsize 0
# 5(levelnames)s - 220411: EPOCH 5 - PROGRESS: at 99.50% examples, 71909 words/s, in_qsize 0, out_qsize 0
# 5(levelnames)s - 220412: worker thread finished; awaiting finish of 0 more threads
# 5(levelnames)s - 220412: EPOCH - 5 : training on 28866702 raw words (11194315 effective words) took 155.6s, 71962 effective words/s
# 5(levelnames)s - 220412: training on a 144333510 raw words (55974882 effective words) took 753.1s, 74326 effective words/s
# Time to train the model: 12.55 mins

# %%
w2v_model.save('/content/drive/MyDrive/recipes.model')
# Out:
# 5(levelnames)s - 220540: saving Word2Vec object under /content/drive/MyDrive/recipes.model, separately None
# 5(levelnames)s - 220540: not storing attribute vectors_norm
# 5(levelnames)s - 220540: not storing attribute cum_table
# 5(levelnames)s - 220541: saved /content/drive/MyDrive/recipes.model

# %%
w2v_model.init_sims(replace=True)
# Out:
# 5(levelnames)s - 220639: precomputing L2-norms of word weight vectors

# %%
w2v_model.wv.most_similar(positive=['chocolate'])
# Out:
# [('choclate', 0.8654007911682129),
#  ('choc', 0.8297751545906067),
#  ('choco', 0.8141728043556213),
#  ('dark_chocolate', 0.8139923810958862),
#  ('bittersweet_chocolate', 0.7554681301116943),
#  ('bittersweet', 0.7355612516403198),
#  ('semisweet_chocolate', 0.7344757914543152),
#  ('butterscotch', 0.7306553721427917),
#  ('hershey', 0.7225421071052551),
#  ('chocolate_ganache', 0.7222815155982971)]

# %%
w2v_model.wv.similarity('brown', 'sugar')
# Out:
# 0.15413524

# %%
w2v_model.wv.most_similar(positive = ['tahini'])
# Out:
# [('hummus', 0.6505939364433289),
#  ('hummous', 0.5677351951599121),
#  ('sumac', 0.5272275805473328),
#  ('sesame', 0.5063362121582031),
#  ('miso', 0.5032118558883667),
#  ('sambal_oelek', 0.5031461119651794),
#  ('can_chickpea', 0.49904292821884155),
#  ('chickpeas', 0.4927641749382019),
#  ('harissa', 0.48904722929000854),
#  ('sesame_oil', 0.4848523736000061)]

# %%
w2v_model.wv.most_similar(positive = ['milk', 'protein'], negative=['tofu'], topn=5)
# Out:
# [('skim_milk', 0.6056066751480103),
#  ('nonfat_milk', 0.5720887184143066),
#  ('nonfat', 0.5487066507339478),
#  ('percent_milk', 0.5205460786819458),
#  ('non_fat', 0.5107308626174927)]
